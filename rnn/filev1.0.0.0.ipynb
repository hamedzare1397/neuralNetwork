# %% [markdown]
# **Start Project Recurent**

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,SimpleRNN
from keras import Input
import pandas as pd
import numpy as np
import math

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

import plotly
import plotly.express as px
import plotly.graph_objects as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# g:\University\NeuralNetwork\تمرین\rnn\filev1.0.0.0.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/g%3A/University/NeuralNetwork/%D8%AA%D9%85%D8%B1%DB%8C%D9%86/rnn/filev1.0.0.0.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from tensorflow import keras
#       <a href='vscode-notebook-cell:/g%3A/University/NeuralNetwork/%D8%AA%D9%85%D8%B1%DB%8C%D9%86/rnn/filev1.0.0.0.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from keras.models import Sequential
#       <a href='vscode-notebook-cell:/g%3A/University/NeuralNetwork/%D8%AA%D9%85%D8%B1%DB%8C%D9%86/rnn/filev1.0.0.0.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from keras.layers import Dense,SimpleRNN
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pd.options.display.max_columns=50
df=pd.read_csv('dataset.csv',encoding='utf-8')
df=df.sort_values('GDate')

# %%
df
# Out:
#      LVal18AFC     PDate     GDate  NumberTrade  VolumeTrade         Value  \
# 1177     وبملت  13950107  20160326          845     14755815  3.599688e+10
# 1176     وبملت  13950108  20160327         2822     44216051  1.104410e+11
# 1175     وبملت  13950109  20160328         2349     38105647  9.555878e+10
# 1174     وبملت  13950110  20160329         1795     25419978  6.379931e+10
# 1173     وبملت  13950111  20160330         2585     37220601  9.539019e+10
# ...        ...       ...       ...          ...          ...           ...
# 4        وبملت  13991223  20210313         9356    281339188  1.109270e+12
# 3        وبملت  13991224  20210314        11100    270006098  1.098370e+12
# 2        وبملت  13991225  20210315        11046    362136753  1.511250e+12
# 1        وبملت  13991226  20210316        13563    499852655  2.104940e+12
# 0        وبملت  13991227  20210317         7213    160731993  6.929920e+11
#
#       ClosePrice  LastPrice  PriceMin  PriceMax  PriceFirst  PriceYesterday
# 1177        2440       2454      2360      2454        2390            2338
# 1176        2498       2470      2451      2556        2501            2440
# 1175        2508       2513      2450      2534        2499            2498
# 1174        2510       2514      2491      2520        2504            2508
# 1173        2563       2550      2510      2609        2510            2510
# ...          ...        ...       ...       ...         ...             ...
# 4           3940       3990      3730      3990        3780            3770
# 3           4070       4020      3990      4150        4080            3940
# 2           4170       4240      3990      4280        4020            4070
# 1           4210       4320      4090      4380        4090            4170
# 0           4310       4330      4230      4380        4320            4210
#
# [1178 rows x 12 columns]

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=df['GDate'],
                         y=df['VolumeTrade'],
                         mode='lines',
                         name='vabemelat',
                         opacity=0.8,
                         line=dict(color='black',width=1)
                         ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c68d772d-62e9-4346-ac35-2ffb31c5ebac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("